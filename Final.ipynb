# %% [markdown]
# # Final
#
#
# The "Final" is a program which search titles and creators of music on archive.org. In archive.org. people may search with a keyword, and the program returns all the titles and creators including the keyword.

# %% [markdown]
# # Purpose
#
# archive.org has a great searching tool; however, for someone, the searching tool may difficult to search what they want for following reasons. First, there are too many searching options. Second, the result from a searching sometimes could not matched. For exmaple, you can see many titles with "!"; however, if you search with "!" you cannot find any result on the website. The purposes of the program are
#
#     1) to search easily
#     2) to find all data which includes searching words.

# %% [markdown]
# # How to Work
#
# The "Final" has four steps to process the result.
#     1. Final gathers all pages related to audio from archive.org and read the data.
#     2. Final calls the data of titles and creator.
#     3. Final returns the data of tiltes and creators as texts.
#     4. Final searches keyword a user input from the returning data and print the result out.

# %% [markdown]
# ## The First Step
# audio pages on archive.org are totla 134. Here, Final can gather the pages using range function in for loop statement. Since, archive.org is created in html, urllip.request and bs4 are necessary to scrap the pages.

# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

my_url = "https://archive.org/details/opensource_audio?sort=titleSorter&page="

page_number = 0
for all_page in range(133):
    all_page = my_url + str(page_number + 1)
    page_number += 1
    print(all_page)
    
    uClient = uReq(all_page)
    pages_html = uClient.read()
    uClient.close()
# Out:
# https://archive.org/details/opensource_audio?sort=titleSorter&page=1
# https://archive.org/details/opensource_audio?sort=titleSorter&page=2
# https://archive.org/details/opensource_audio?sort=titleSorter&page=3
# https://archive.org/details/opensource_audio?sort=titleSorter&page=4
# https://archive.org/details/opensource_audio?sort=titleSorter&page=5
# https://archive.org/details/opensource_audio?sort=titleSorter&page=6
# https://archive.org/details/opensource_audio?sort=titleSorter&page=7
# https://archive.org/details/opensource_audio?sort=titleSorter&page=8
# https://archive.org/details/opensource_audio?sort=titleSorter&page=9
# https://archive.org/details/opensource_audio?sort=titleSorter&page=10
# https://archive.org/details/opensource_audio?sort=titleSorter&page=11
# https://archive.org/details/opensource_audio?sort=titleSorter&page=12
# https://archive.org/details/opensource_audio?sort=titleSorter&page=13
# https://archive.org/details/opensource_audio?sort=titleSorter&page=14
# ...

# %% [markdown]
# ## Bring Titles and Creators from Containers

# %%
my_url = "https://archive.org/details/opensource_audio?sort=titleSorter&page=1"

uClient = uReq(my_url)
pages_html = uClient.read()
uClient.close()

soups = soup(pages_html, "html.parser")

containers = soups.findAll('div', {"class": "C234"})

for container in containers:
    creators = container.findAll('span', {"class": "byv"})
    titles = container.findAll('div', {"class": "ttl"})
    print(titles)
# Out:
# []
# [<div class="ttl">
#                 !              </div>]
# []
# [<div class="ttl">
#                 ! - 0:00              </div>]
# []
# [<div class="ttl">
#                 ! Adiós Princesita! / Bye bye, Little princess!              </div>]
# []
# [<div class="ttl">
#                 ! L ‌‌.‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌              </div>]
# []
# [<div class="ttl">
#                 ! السلمية دين من              </div>]
# []
# [<div class="ttl">
#                 ! ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌‌‌ Qur An              </div>]
# []
# [<div class="ttl">
#                 ! ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌‌‌ Qur An              </div>]
# []
# [<div class="ttl">
#                 !! ..              </div>]
# []
# [<div class="ttl">
#                 !!!              </div>]
# []
# [<div class="ttl">
#                 !!!              </div>]
# []
# [<div class="ttl">
#                 !!! !!!              </div>]
# []
# [<div class="ttl">
# ...

# %% [markdown]
# ## Returning Titles and Creators as Text

# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup


my_url = "https://archive.org/details/opensource_audio?sort=titleSorter&page=1"

uClient = uReq(my_url)
pages_html = uClient.read()
uClient.close()

soups = soup(pages_html, "html.parser")

containers = soups.findAll('div', {"class": "C234"})

for container in containers:
    creators = container.findAll('span', {"class": "byv"})
    titles = container.findAll('div', {"class": "ttl"})

    each_title = ' '
    for title in titles:
        each_title = each_title + title.text
        print(each_title.lstrip())
# Out:
# !
# ! - 0:00
# ! Adiós Princesita! / Bye bye, Little princess!
# ! L ‌‌.‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌
# ! السلمية دين من
# ! ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌‌‌ Qur An
# ! ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌‌‌ Qur An
# !! ..
# !!!
# !!!
# !!! !!!
# !!! CD AO VIVO GELEIA CIRIO MACAPAZINHO ( MARCANTE )
# !!! الله عز وجل.... يتودد إليك
# !!!!!
# !!!!!
# !!!!!!! CD AO VIVO STRADA PRESSÃ O = BY DJ GELEIA OFC DE MACAPÁ
# !!!!Dire Straits - You And Your Friend.mp3
# !!!IDmen-singl
# !!!مشكلة إسقاط العلماء
# !!.
# !!7HG%hg%%Vf%Fd%Q%Cx%T%E%As%Pl%NH%Vc%Q%.mp3
# !0 Year Plan
# !0007!388
# !2-28-09 Survival Of The Fittest
# !3 a 13.30
# !31tr%nhgF%J%Vf%aQ5Mk%Lo%As%vb%cx%Zs%S%.mp3
# !Adios a la Maestra ! Pedro Bonifacio Palacios,ALMAFUERTE,
# !Arranca Valeriano¡ 24/11/2013
# !HANDZUP! NETWORK MYXXTAPES Presents: 'STRICTLY FEMCEES'
# !HANDZUP! NETWORK RADI-YO! Episode: #001 (debut show on Rapstation)
# !HANDZUP! NETWORK RADI-YO! Show (on Rapstation) {Episode: #002}
# !hbg%mn%cds%G5Efv%jh%aq%Ki%.mp3
# !m@9!n3333
# ...

# %% [markdown]
# # Seach

# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup


my_url = "https://archive.org/details/opensource_audio?sort=titleSorter&page=1"

uClient = uReq(my_url)
pages_html = uClient.read()
uClient.close()

soups = soup(pages_html, "html.parser")

containers = soups.findAll('div', {"class": "C234"})

A = input(print("please: "))
for container in containers:
    creators = container.findAll('span', {"class": "byv"})
    titles = container.findAll('div', {"class": "ttl"})

    each_title = ' '
    for title in titles:
        each_title = each_title + title.text
        
    each_creator = ' '
    for creator in creators:
        each_creator = each_creator + creator.text

    lists = "title: " + each_title.lstrip() + ",   " + "creator: " + each_creator.lstrip()

    if A in lists:
        print(lists)
# Out:
# please:
# None1000
# title: " 1000 microgramms of love "              ,   creator: " hoffmans bicycle "

# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup


my_url = "https://archive.org/details/opensource_audio?sort=titleSorter&page=1"

uClient = uReq(my_url)
pages_html = uClient.read()
uClient.close()

soups = soup(pages_html, "html.parser")

containers = soups.findAll('div', {"class": "C234"})

A = input(print("please: "))
for container in containers:
    creators = container.findAll('span', {"class": "byv"})
    titles = container.findAll('div', {"class": "ttl"})

    each_title = ' '
    for title in titles:
        each_title = each_title + title.text
        
    each_creator = ' '
    for creator in creators:
        each_creator = each_creator + creator.text

    lists = "title: " + each_title.lstrip() + ",   " + "creator: " + each_creator.lstrip()

    if A in lists:
        print(lists)
# Out:
# please:
# None!
# title: !              ,   creator:
# title: ! - 0:00              ,   creator: Yukiga Futte Uresii
# title: ! Adiós Princesita! / Bye bye, Little princess!              ,   creator: Carlos Echepare Chapartegui MINISON
# title: ! L ‌‌.‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌              ,   creator:
# title: ! السلمية دين من              ,   creator: صفحة لهيب الحرب
# title: ! ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌‌‌ Qur An              ,   creator:
# title: ! ‌‌‌‌‌‌‌‌ ‌‌‌‌‌‌‌‌‌‌‌‌‌‌ Qur An              ,   creator:
# title: !! ..              ,   creator: bc_hms
# title: !!!              ,   creator:
# title: !!!              ,   creator: w
# title: !!! !!!              ,   creator:
# title: !!! CD AO VIVO GELEIA CIRIO MACAPAZINHO ( MARCANTE )              ,   creator:
# title: !!! الله عز وجل.... يتودد إليك              ,   creator:
# title: !!!!!              ,   creator:
# title: !!!!!              ,   creator:
# ...
